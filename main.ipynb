# %%
import pandas as pd
import requests
import datetime
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("API_KEY")


city_name = ["Paris","Marseille","Lyon","Toulouse","Nice","Nantes","Strasbourg","Montpellier","Bordeaux","Lille","Rennes","Reims","Le Havre","Saint-Etienne","Toulon","Grenoble","Dijon","Angers","Nîmes","Villeurbanne"]

weather_data_list = []

# Obtenir les coordonnées géographiques de la ville
for ville in city_name :
    geo_url = f"http://api.openweathermap.org/geo/1.0/direct?q={ville}&limit=1&appid={api_key}&units=metric"
    geo_response = requests.get(geo_url)
    geo_data = geo_response.json()

    if geo_response.status_code == 200 and geo_data:
        # Utiliser les coordonnées géographiques pour obtenir les données météorologiques actuelles
        lat, lon = geo_data[0]["lat"], geo_data[0]["lon"]
        weather_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=metric&appid={api_key}"
        weather_response = requests.get(weather_url)
        
        if weather_response.status_code == 200:
            weather_data = weather_response.json()
            weather_data_list.append([
                ville,
                weather_data["main"]["temp"],
                weather_data["main"]["temp_min"],
                weather_data["main"]["temp_max"],
                weather_data["main"]["feels_like"],
                weather_data["main"]["pressure"],
                weather_data["main"]["humidity"],
                weather_data["wind"]["speed"],
                weather_data["wind"]["deg"],
                datetime.datetime.fromtimestamp(weather_data["sys"]["sunrise"]),
                datetime.datetime.fromtimestamp(weather_data["sys"]["sunrise"])
                
            ])
        else:
            print("Une erreur s'est produite lors de la requête à l'API OpenWeather")
    else:
        print("La ville spécifiée est introuvable ou une erreur s'est produite lors de la requête à l'API OpenWeather Geo.")
        
        
weather_df = pd.DataFrame(weather_data_list,columns=[
    "Ville",
    "Température",
    "Température Min",
    "Température Max",
    "Température ressentie",
    "Pression",
    "Humidité",
    "Vitesse du vent",
    "Direction du vent",
    "Levé du soleil",
    "Coucher du soleil"
])

weather_df.to_csv('weather_df.csv')
weather_df
# Out:
# {'coord': {'lon': 2.32, 'lat': 48.8589}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 9.56, 'feels_like': 6.47, 'temp_min': 8.75, 'temp_max': 11.02, 'pressure': 1026, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 50}, 'clouds': {'all': 20}, 'dt': 1680522094, 'sys': {'type': 2, 'id': 2012208, 'country': 'FR', 'sunrise': 1680499498, 'sunset': 1680546175}, 'timezone': 7200, 'id': 6545270, 'name': 'Palais-Royal', 'cod': 200}
# {'coord': {'lon': 5.37, 'lat': 43.2962}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 19.03, 'feels_like': 18.06, 'temp_min': 16.22, 'temp_max': 19.84, 'pressure': 1011, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 4.92, 'deg': 232, 'gust': 8.49}, 'clouds': {'all': 0}, 'dt': 1680522691, 'sys': {'type': 2, 'id': 80238, 'country': 'FR', 'sunrise': 1680499051, 'sunset': 1680545158}, 'timezone': 7200, 'id': 2995469, 'name': 'Marseille', 'cod': 200}
# {'coord': {'lon': 4.832, 'lat': 45.7578}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 8.91, 'feels_like': 5.33, 'temp_min': 7.94, 'temp_max': 9.99, 'pressure': 1019, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 7.72, 'deg': 340}, 'clouds': {'all': 100}, 'dt': 1680522624, 'sys': {'type': 1, 'id': 6505, 'country': 'FR', 'sunrise': 1680499062, 'sunset': 1680545406}, 'timezone': 7200, 'id': 8015556, 'name': 'Vieux Lyon', 'cod': 200}
# {'coord': {'lon': 1.4442, 'lat': 43.6045}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 11.86, 'feels_like': 10.82, 'temp_min': 10.43, 'temp_max': 11.97, 'pressure': 1021, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 5.66, 'deg': 290}, 'clouds': {'all': 100}, 'dt': 1680522593, 'sys': {'type': 1, 'id': 6467, 'country': 'FR', 'sunrise': 1680499978, 'sunset': 1680546115}, 'timezone': 7200, 'id': 2972315, 'name': 'Toulouse', 'cod': 200}
# {'coord': {'lon': 7.2684, 'lat': 43.7009}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 18.08, 'feels_like': 17.59, 'temp_min': 16.92, 'temp_max': 21.91, 'pressure': 1010, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 200}, 'clouds': {'all': 20}, 'dt': 1680522467, 'sys': {'type': 1, 'id': 6515, 'country': 'FR', 'sunrise': 1680498577, 'sunset': 1680544721}, 'timezone': 7200, 'id': 2990440, 'name': 'Nice', 'cod': 200}
# {'coord': {'lon': -1.5541, 'lat': 47.2186}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 8.06, 'feels_like': 5.11, 'temp_min': 7.9, 'temp_max': 8.06, 'pressure': 1025, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 60}, 'clouds': {'all': 100}, 'dt': 1680522204, 'sys': {'type': 1, 'id': 6574, 'country': 'FR', 'sunrise': 1680500517, 'sunset': 1680547015}, 'timezone': 7200, 'id': 2990969, 'name': 'Nantes', 'cod': 200}
# {'coord': {'lon': 7.7507, 'lat': 48.5846}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 8.1, 'feels_like': 4.44, 'temp_min': 7.12, 'temp_max': 9.43, 'pressure': 1026, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 70}, 'clouds': {'all': 100}, 'dt': 1680522136, 'sys': {'type': 1, 'id': 6595, 'country': 'FR', 'sunrise': 1680498212, 'sunset': 1680544855}, 'timezone': 7200, 'id': 2973781, 'name': 'Arrondissement de Strasbourg', 'cod': 200}
# {'coord': {'lon': 3.8767, 'lat': 43.6112}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 17.1, 'feels_like': 15.94, 'temp_min': 16.27, 'temp_max': 17.48, 'pressure': 1014, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 340}, 'clouds': {'all': 0}, 'dt': 1680522381, 'sys': {'type': 2, 'id': 2038454, 'country': 'FR', 'sunrise': 1680499394, 'sunset': 1680545531}, 'timezone': 7200, 'id': 6454034, 'name': 'Montpellier', 'cod': 200}
# {'coord': {'lon': -0.58, 'lat': 44.8412}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 13.15, 'feels_like': 12.04, 'temp_min': 13.15, 'temp_max': 14.63, 'pressure': 1022, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 50}, 'clouds': {'all': 75}, 'dt': 1680522594, 'sys': {'type': 1, 'id': 6450, 'country': 'FR', 'sunrise': 1680500404, 'sunset': 1680546660}, 'timezone': 7200, 'id': 3031582, 'name': 'Bordeaux', 'cod': 200}
# {'coord': {'lon': 3.0635, 'lat': 50.6366}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 10.44, 'feels_like': 8.85, 'temp_min': 8.53, 'temp_max': 11.49, 'pressure': 1028, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 5.66, 'deg': 50}, 'clouds': {'all': 0}, 'dt': 1680522293, 'sys': {'type': 2, 'id': 2011132, 'country': 'FR', 'sunrise': 1680499215, 'sunset': 1680546101}, 'timezone': 7200, 'id': 6454414, 'name': 'Lille', 'cod': 200}
# {'coord': {'lon': -1.68, 'lat': 48.1113}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 5.94, 'feels_like': 3.24, 'temp_min': 5.94, 'temp_max': 8.57, 'pressure': 1027, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 50}, 'clouds': {'all': 100}, 'dt': 1680522076, 'sys': {'type': 1, 'id': 6565, 'country': 'FR', 'sunrise': 1680500498, 'sunset': 1680547094}, 'timezone': 7200, 'id': 6432801, 'name': 'Rennes', 'cod': 200}
# {'coord': {'lon': 4.0319, 'lat': 49.2578}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 10, 'feels_like': 7.19, 'temp_min': 9.59, 'temp_max': 10, 'pressure': 1026, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 60}, 'clouds': {'all': 20}, 'dt': 1680522458, 'sys': {'type': 1, 'id': 6553, 'country': 'FR', 'sunrise': 1680499065, 'sunset': 1680545786}, 'timezone': 7200, 'id': 6454251, 'name': 'Reims', 'cod': 200}
# {'coord': {'lon': 0.108, 'lat': 49.4939}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 9.51, 'feels_like': 7.34, 'temp_min': 9.51, 'temp_max': 9.86, 'pressure': 1027, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 70}, 'clouds': {'all': 0}, 'dt': 1680522610, 'sys': {'type': 1, 'id': 6533, 'country': 'FR', 'sunrise': 1680499991, 'sunset': 1680546743}, 'timezone': 7200, 'id': 3003796, 'name': 'Le Havre', 'cod': 200}
# {'coord': {'lon': 4.3873, 'lat': 45.4401}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 7.17, 'feels_like': 3.78, 'temp_min': 7.17, 'temp_max': 7.64, 'pressure': 1019, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 5.66, 'deg': 340}, 'clouds': {'all': 100}, 'dt': 1680522382, 'sys': {'type': 1, 'id': 6508, 'country': 'FR', 'sunrise': 1680499184, 'sunset': 1680545497}, 'timezone': 7200, 'id': 2980291, 'name': 'Saint-Etienne', 'cod': 200}
# {'coord': {'lon': 5.9305, 'lat': 43.1257}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 17.52, 'feels_like': 16.74, 'temp_min': 15.6, 'temp_max': 22.41, 'pressure': 1010, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1680522225, 'sys': {'type': 2, 'id': 2005831, 'country': 'FR', 'sunrise': 1680498924, 'sunset': 1680545016}, 'timezone': 7200, 'id': 2972328, 'name': 'Toulon', 'cod': 200}
# {'coord': {'lon': 5.7358, 'lat': 45.1876}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 9.69, 'feels_like': 9.69, 'temp_min': 8.08, 'temp_max': 11.66, 'pressure': 1017, 'humidity': 92}, 'visibility': 1255, 'wind': {'speed': 0.89, 'deg': 44, 'gust': 4.92}, 'clouds': {'all': 100}, 'dt': 1680522365, 'sys': {'type': 2, 'id': 2004515, 'country': 'FR', 'sunrise': 1680498873, 'sunset': 1680545160}, 'timezone': 7200, 'id': 6454071, 'name': 'Grenoble', 'cod': 200}
# {'coord': {'lon': 5.0415, 'lat': 47.3216}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 6.86, 'feels_like': 3.39, 'temp_min': 6.8, 'temp_max': 9.01, 'pressure': 1022, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 5.66, 'deg': 20}, 'clouds': {'all': 100}, 'dt': 1680522512, 'sys': {'type': 1, 'id': 6586, 'country': 'FR', 'sunrise': 1680498930, 'sunset': 1680545436}, 'timezone': 7200, 'id': 3006622, 'name': 'Larrey', 'cod': 200}
# {'coord': {'lon': -0.5516, 'lat': 47.474}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 9.48, 'feels_like': 7.21, 'temp_min': 8.16, 'temp_max': 9.48, 'pressure': 1025, 'humidity': 65, 'sea_level': 1025, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 4.35, 'deg': 54, 'gust': 5.12}, 'clouds': {'all': 47}, 'dt': 1680522749, 'sys': {'type': 2, 'id': 2032547, 'country': 'FR', 'sunrise': 1680500263, 'sunset': 1680546788}, 'timezone': 7200, 'id': 3037656, 'name': 'Angers', 'cod': 200}
# {'coord': {'lon': 4.3601, 'lat': 43.8374}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 16.04, 'feels_like': 14.95, 'temp_min': 15.07, 'temp_max': 17.44, 'pressure': 1014, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 9.77, 'deg': 10, 'gust': 14.92}, 'clouds': {'all': 20}, 'dt': 1680522494, 'sys': {'type': 1, 'id': 6599, 'country': 'FR', 'sunrise': 1680499268, 'sunset': 1680545426}, 'timezone': 7200, 'id': 2990363, 'name': 'Nîmes', 'cod': 200}
# {'coord': {'lon': 4.8868, 'lat': 45.7734}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 8.81, 'feels_like': 5.06, 'temp_min': 7.98, 'temp_max': 10.03, 'pressure': 1019, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 8.23, 'deg': 350}, 'clouds': {'all': 100}, 'dt': 1680522749, 'sys': {'type': 1, 'id': 6505, 'country': 'FR', 'sunrise': 1680499048, 'sunset': 1680545393}, 'timezone': 7200, 'id': 2968254, 'name': 'Villeurbanne', 'cod': 200}
#             Ville  Longitude  Température  Température Min  Température Max  \
# 0           Paris     2.3200         9.56             8.75            11.02
# 1       Marseille     5.3700        19.03            16.22            19.84
# 2            Lyon     4.8320         8.91             7.94             9.99
# 3        Toulouse     1.4442        11.86            10.43            11.97
# 4            Nice     7.2684        18.08            16.92            21.91
# 5          Nantes    -1.5541         8.06             7.90             8.06
# 6      Strasbourg     7.7507         8.10             7.12             9.43
# 7     Montpellier     3.8767        17.10            16.27            17.48
# 8        Bordeaux    -0.5800        13.15            13.15            14.63
# 9           Lille     3.0635        10.44             8.53            11.49
# 10         Rennes    -1.6800         5.94             5.94             8.57
# 11          Reims     4.0319        10.00             9.59            10.00
# 12       Le Havre     0.1080         9.51             9.51             9.86
# 13  Saint-Etienne     4.3873         7.17             7.17             7.64
# 14         Toulon     5.9305        17.52            15.60            22.41
# 15       Grenoble     5.7358         9.69             8.08            11.66
# 16          Dijon     5.0415         6.86             6.80             9.01
# 17         Angers    -0.5516         9.48             8.16             9.48
# 18          Nîmes     4.3601        16.04            15.07            17.44
# 19   Villeurbanne     4.8868         8.81             7.98            10.03
#
#     Température ressentie  Pression  Humidité  Vitesse du vent  \
# 0                    6.47      1026        57             6.69
# 1                   18.06      1011        41             4.92
# 2                    5.33      1019        83             7.72
# 3                   10.82      1021        66             5.66
# 4                   17.59      1010        63             4.63
# 5                    5.11      1025        76             5.14
# 6                    4.44      1026        53             7.20
# 7                   15.94      1014        41             6.17
# 8                   12.04      1022        58             3.60
# 9                    8.85      1028        50             5.66
# 10                   3.24      1027        75             3.60
# 11                   7.19      1026        53             6.17
# 12                   7.34      1027        66             4.12
# 13                   3.78      1019        87             5.66
# 14                  16.74      1010        54             4.63
# 15                   9.69      1017        92             0.89
# 16                   3.39      1022        76             5.66
# 17                   7.21      1025        65             4.35
# 18                  14.95      1014        48             9.77
# 19                   5.06      1019        81             8.23
#
#     Direction du vent      Levé du soleil   Coucher du soleil
# 0                  50 2023-04-03 07:24:58 2023-04-03 07:24:58
# 1                 232 2023-04-03 07:17:31 2023-04-03 07:17:31
# 2                 340 2023-04-03 07:17:42 2023-04-03 07:17:42
# 3                 290 2023-04-03 07:32:58 2023-04-03 07:32:58
# 4                 200 2023-04-03 07:09:37 2023-04-03 07:09:37
# 5                  60 2023-04-03 07:41:57 2023-04-03 07:41:57
# 6                  70 2023-04-03 07:03:32 2023-04-03 07:03:32
# 7                 340 2023-04-03 07:23:14 2023-04-03 07:23:14
# 8                  50 2023-04-03 07:40:04 2023-04-03 07:40:04
# 9                  50 2023-04-03 07:20:15 2023-04-03 07:20:15
# 10                 50 2023-04-03 07:41:38 2023-04-03 07:41:38
# 11                 60 2023-04-03 07:17:45 2023-04-03 07:17:45
# 12                 70 2023-04-03 07:33:11 2023-04-03 07:33:11
# 13                340 2023-04-03 07:19:44 2023-04-03 07:19:44
# 14                220 2023-04-03 07:15:24 2023-04-03 07:15:24
# 15                 44 2023-04-03 07:14:33 2023-04-03 07:14:33
# 16                 20 2023-04-03 07:15:30 2023-04-03 07:15:30
# 17                 54 2023-04-03 07:37:43 2023-04-03 07:37:43
# 18                 10 2023-04-03 07:21:08 2023-04-03 07:21:08
# 19                350 2023-04-03 07:17:28 2023-04-03 07:17:28

# %%
import sqlite3
import pandas as pd 

connexion = sqlite3.connect('bdd.db')

weather_df.to_sql('weather_data', connexion,if_exists='replace', index=False)

connexion.close()

# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()
api_key = os.getenv("API_KEY")



geo_url = f"http://api.openweathermap.org/geo/1.0/direct?q=Lille&limit=1&appid={api_key}"
geo_response = requests.get(geo_url)
geo_data = geo_response.json()

if geo_response.status_code == 200 and geo_data:
    lat, lon = geo_data[0]["lat"], geo_data[0]["lon"]
    weather_url = f"https://api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&units=metric&cnt=3&appid={api_key}"
    weather_response = requests.get(weather_url)
    weather_data = weather_response.json()
    print(weather_data)
# Out:
# {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}
